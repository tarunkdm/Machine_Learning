# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.shape
# Out:
# (891, 12)

# %%
df = pd.get_dummies(df, columns = ['Sex'], drop_first= True)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name   Age  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris  22.0      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                               Heikkinen, Miss. Laina  26.0      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                             Allen, Mr. William Henry  35.0      0      0
# ..                                                 ...   ...    ...    ...
# ...

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name        Age  SibSp  \
# 0                              Braund, Mr. Owen Harris  22.000000      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.000000      1
# 2                               Heikkinen, Miss. Laina  26.000000      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.000000      1
# 4                             Allen, Mr. William Henry  35.000000      0
# ..                                                 ...        ...    ...
# ...

# %%
df = df.drop(["Name", 'Ticket','Cabin'], axis = 1)

# %%
df = pd.get_dummies(df, columns = ['Embarked'])

# %%
df
# Out:
#      PassengerId  Survived  Pclass        Age  SibSp  Parch     Fare  \
# 0              1         0       3  22.000000      1      0   7.2500
# 1              2         1       1  38.000000      1      0  71.2833
# 2              3         1       3  26.000000      0      0   7.9250
# 3              4         1       1  35.000000      1      0  53.1000
# 4              5         0       3  35.000000      0      0   8.0500
# ..           ...       ...     ...        ...    ...    ...      ...
# 886          887         0       2  27.000000      0      0  13.0000
# 887          888         1       1  19.000000      0      0  30.0000
# 888          889         0       3  29.699118      1      2  23.4500
# 889          890         1       1  26.000000      0      0  30.0000
# 890          891         0       3  32.000000      0      0   7.7500
#
#      Sex_male  Embarked_C  Embarked_Q  Embarked_S
# 0           1           0           0           1
# ...

# %% [markdown]
# # import seaborn as sns
# _=sns.boxplot(x = 'Sex', y= 'Age', data = df)

# %% [markdown]
# # X = df.drop(['Survived','PassengerId','Ticket','Name','Cabin','Embarked'], axis = 1)
# y = df['Survived']

# %% [markdown]
# # X.head()

# %%
X.isna().sum()
# Out:
# Pclass      0
# Sex         0
# Age       177
# SibSp       0
# Parch       0
# Fare        0
# dtype: int64

# %%
X.dtypes
# Out:
# Pclass      int64
# Sex        object
# Age       float64
# SibSp       int64
# Parch       int64
# Fare      float64
# dtype: object

# %%
X = pd.get_dummies(X, columns = ['Sex'], drop_first= True)

# %%
X.corr()
# Out:
#             Pclass       Age     SibSp     Parch      Fare  Sex_male
# Pclass    1.000000 -0.369226  0.083081  0.018443 -0.549500  0.131900
# Age      -0.369226  1.000000 -0.308247 -0.189119  0.096067  0.093254
# SibSp     0.083081 -0.308247  1.000000  0.414838  0.159651 -0.114631
# Parch     0.018443 -0.189119  0.414838  1.000000  0.216225 -0.245489
# Fare     -0.549500  0.096067  0.159651  0.216225  1.000000 -0.182333
# Sex_male  0.131900  0.093254 -0.114631 -0.245489 -0.182333  1.000000

# %%
sns.set(font_scale=1)
plt.figure(figsize=(10,6))
_ = sns.heatmap(df.corr(),annot=True,annot_kws={"size": 15},fmt='.1f',cmap='PiYG', linewidths=.5)
plt.yticks(rotation=0)
# Out:
# (array([0.5, 1.5, 2.5, 3.5, 4.5, 5.5, 6.5]),
#  <a list of 7 Text major ticklabel objects>)

# %%
plt.figure(figsize=None)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-61-40c5d9d8ea68> in <module>
# ----> 1 plt.figure(figsize=None)
#
# TypeError: 'module' object is not callable

# %%
X['Age'] = X['Age'].fillna(X['Age'].mean())

# %%
X
# Out:
#      Pclass        Age  SibSp  Parch     Fare  Sex_male
# 0         3  22.000000      1      0   7.2500         1
# 1         1  38.000000      1      0  71.2833         0
# 2         3  26.000000      0      0   7.9250         0
# 3         1  35.000000      1      0  53.1000         0
# 4         3  35.000000      0      0   8.0500         1
# ..      ...        ...    ...    ...      ...       ...
# 886       2  27.000000      0      0  13.0000         1
# 887       1  19.000000      0      0  30.0000         0
# 888       3  29.699118      1      2  23.4500         0
# 889       1  26.000000      0      0  30.0000         1
# 890       3  32.000000      0      0   7.7500         1
#
# [891 rows x 6 columns]

# %%
X.isna().sum()
# Out:
# Pclass      0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Sex_male    0
# dtype: int64

# %% [markdown]
# # from sklearn.model_selection import train_test_split
# X_train, X_test, y_train, y_test = train_test_split(X, y , test_size = 0.3, random_state=  42, stratify = y)

# %%
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %% [markdown]
# # 3

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X = scaler.fit_transform(X)

# %% [markdown]
# # 4

# %%
X.shape
# Out:
# (891, 6)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X, y)
# Out:
# LogisticRegression()

# %% [markdown]
# # 5

# %%
X_test =  pd.read_csv('test.csv')
X_test.shape
# Out:
# (418, 11)

# %%
X_test_1 = X_test.drop(['PassengerId','Ticket','Name','Cabin','Embarked'], axis = 1)
_ =  sns.boxplot(x= 'Sex', y = 'Age', data = X_test)
X_test_1
# Out:
#      Pclass     Sex   Age  SibSp  Parch      Fare
# 0         3    male  34.5      0      0    7.8292
# 1         3  female  47.0      1      0    7.0000
# 2         2    male  62.0      0      0    9.6875
# 3         3    male  27.0      0      0    8.6625
# 4         3  female  22.0      1      1   12.2875
# ..      ...     ...   ...    ...    ...       ...
# 413       3    male   NaN      0      0    8.0500
# 414       1  female  39.0      0      0  108.9000
# 415       3    male  38.5      0      0    7.2500
# 416       3    male   NaN      0      0    8.0500
# 417       3    male   NaN      1      1   22.3583
#
# [418 rows x 6 columns]

# %%
X_test_1 = pd.get_dummies(X_test_1, columns = ['Sex'], drop_first= True)
X_test_1
# Out:
#      Pclass   Age  SibSp  Parch      Fare  Sex_male
# 0         3  34.5      0      0    7.8292         1
# 1         3  47.0      1      0    7.0000         0
# 2         2  62.0      0      0    9.6875         1
# 3         3  27.0      0      0    8.6625         1
# 4         3  22.0      1      1   12.2875         0
# ..      ...   ...    ...    ...       ...       ...
# 413       3   NaN      0      0    8.0500         1
# 414       1  39.0      0      0  108.9000         0
# 415       3  38.5      0      0    7.2500         1
# 416       3   NaN      0      0    8.0500         1
# 417       3   NaN      1      1   22.3583         1
#
# [418 rows x 6 columns]

# %%
X_test_1['Age'] = X_test_1['Age'].fillna(X_test['Age'].mean())

# %%
X_test_1
# Out:
#      Pclass       Age  SibSp  Parch      Fare  Sex_male
# 0         3  34.50000      0      0    7.8292         1
# 1         3  47.00000      1      0    7.0000         0
# 2         2  62.00000      0      0    9.6875         1
# 3         3  27.00000      0      0    8.6625         1
# 4         3  22.00000      1      1   12.2875         0
# ..      ...       ...    ...    ...       ...       ...
# 413       3  30.27259      0      0    8.0500         1
# 414       1  39.00000      0      0  108.9000         0
# 415       3  38.50000      0      0    7.2500         1
# 416       3  30.27259      0      0    8.0500         1
# 417       3  30.27259      1      1   22.3583         1
#
# [418 rows x 6 columns]

# %%
X_test_1['Fare'] = X_test_1['Fare'].fillna(X_test_1['Fare'].mean())

# %%
X_test_1.isna().sum()
# Out:
# Pclass      0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Sex_male    0
# dtype: int64

# %%
X_test_1.shape
# Out:
# (418, 6)

# %%
prediction = model.predict(X_test_1)
prediction.shape
# Out:
# (418,)

# %%
X_test['Survived'] = prediction

# %%
X_test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# ...

# %%
X_test.to_csv('kaggle.csv')
